# %%
import pandas as pd
from sqlalchemy import create_engine

import pymysql
pymysql.install_as_MySQLdb()

# %%
csv_file = "../team/sportsref_download_AFC_2018.csv"
AFC_df = pd.read_csv(csv_file)
AFC_df
# Out:
#                       Tm   W   L  T   W-L%   PF   PA   PD   MoV  SoS  SRS  \
# 0   New England Patriots  11   5  0  0.688  436  325  111   6.9 -1.8  5.2
# 1         Miami Dolphins   7   9  0  0.438  319  433 -114  -7.1 -1.7 -8.8
# 2          Buffalo Bills   6  10  0  0.375  269  374 -105  -6.6 -0.3 -6.9
# 3          New York Jets   4  12  0  0.250  333  441 -108  -6.8 -1.1 -7.8
# 4       Baltimore Ravens  10   6  0  0.625  389  287  102   6.4  0.6  7.0
# 5    Pittsburgh Steelers   9   6  1  0.594  428  360   68   4.3  1.3  5.6
# 6       Cleveland Browns   7   8  1  0.469  359  392  -33  -2.1  1.7 -0.3
# 7     Cincinnati Bengals   6  10  0  0.375  368  455  -87  -5.4  2.0 -3.4
# 8         Houston Texans  11   5  0  0.688  402  316   86   5.4 -1.5  3.8
# 9     Indianapolis Colts  10   6  0  0.625  433  344   89   5.6 -2.2  3.4
# 10      Tennessee Titans   9   7  0  0.563  310  303    7   0.4 -0.2  0.2
# 11  Jacksonville Jaguars   5  11  0  0.313  245  316  -71  -4.4  0.4 -4.0
# 12    Kansas City Chiefs  12   4  0  0.750  565  421  144   9.0 -0.1  8.9
# 13  Los Angeles Chargers  12   4  0  0.750  428  329   99   6.2 -0.2  6.0
# 14        Denver Broncos   6  10  0  0.375  329  349  -20  -1.3  0.7 -0.5
# 15       Oakland Raiders   4  12  0  0.250  290  467 -177 -11.1  1.8 -9.3
#
#     OSRS  DSRS
# 0    3.1   2.1
# 1   -3.6  -5.2
# 2   -6.3  -0.6
# 3   -2.0  -5.9
# 4    0.6   6.4
# 5    3.9   1.7
# 6   -1.0   0.6
# 7    0.0  -3.4
# 8    2.4   1.4
# 9    3.9  -0.6
# 10  -3.2   3.5
# 11  -8.1   4.0
# 12  12.6  -3.8
# 13   3.0   2.9
# 14  -3.6   3.1
# 15  -5.2  -4.1

# %%
csv_file = "../team/sportsref_download_NFC_2018.csv"
NFC_df = pd.read_csv(csv_file)
NFC_df
# Out:
#                       Tm   W   L  T   W-L%   PF   PA   PD   MoV  SoS   SRS  \
# 0         Dallas Cowboys  10   6  0  0.625  339  324   15   0.9  0.2   1.1
# 1    Philadelphia Eagles   9   7  0  0.563  367  348   19   1.2  0.5   1.7
# 2    Washington Redskins   7   9  0  0.438  281  359  -78  -4.9 -0.1  -4.9
# 3        New York Giants   5  11  0  0.313  369  412  -43  -2.7  0.5  -2.2
# 4          Chicago Bears  12   4  0  0.750  421  283  138   8.6 -2.3   6.3
# 5      Minnesota Vikings   8   7  1  0.531  360  341   19   1.2 -0.6   0.6
# 6      Green Bay Packers   6   9  1  0.406  376  400  -24  -1.5 -1.2  -2.7
# 7          Detroit Lions   6  10  0  0.375  324  360  -36  -2.3 -0.8  -3.0
# 8     New Orleans Saints  13   3  0  0.813  504  353  151   9.4  0.6  10.1
# 9      Carolina Panthers   7   9  0  0.438  376  382   -6  -0.4  1.3   0.9
# 10       Atlanta Falcons   7   9  0  0.438  414  423   -9  -0.6  0.4  -0.1
# 11  Tampa Bay Buccaneers   5  11  0  0.313  396  464  -68  -4.3  1.7  -2.6
# 12      Los Angeles Rams  13   3  0  0.813  527  384  143   8.9 -0.4   8.5
# 13      Seattle Seahawks  10   6  0  0.625  428  347   81   5.1 -0.6   4.5
# 14   San Francisco 49ers   4  12  0  0.250  342  435  -93  -5.8  0.3  -5.5
# 15     Arizona Cardinals   3  13  0  0.188  225  425 -200 -12.5  1.0 -11.5
#
#     OSRS  DSRS
# 0   -1.9   2.9
# 1    0.0   1.8
# 2   -5.6   0.6
# 3    0.8  -2.9
# 4    1.5   4.8
# 5   -1.2   1.8
# 6    0.0  -2.7
# 7   -3.3   0.3
# 8    7.9   2.2
# 9    0.1   0.8
# 10   2.5  -2.6
# 11   2.0  -4.6
# 12   9.5  -1.1
# 13   3.0   1.5
# 14  -2.5  -3.1
# 15  -9.6  -1.9

# %%
team_df = AFC_df.append(NFC_df)
team_df = team_df.reset_index(drop=True)
team_df
# Out:
#                       Tm   W   L  T   W-L%   PF   PA   PD   MoV  SoS   SRS  \
# 0   New England Patriots  11   5  0  0.688  436  325  111   6.9 -1.8   5.2
# 1         Miami Dolphins   7   9  0  0.438  319  433 -114  -7.1 -1.7  -8.8
# 2          Buffalo Bills   6  10  0  0.375  269  374 -105  -6.6 -0.3  -6.9
# 3          New York Jets   4  12  0  0.250  333  441 -108  -6.8 -1.1  -7.8
# 4       Baltimore Ravens  10   6  0  0.625  389  287  102   6.4  0.6   7.0
# 5    Pittsburgh Steelers   9   6  1  0.594  428  360   68   4.3  1.3   5.6
# 6       Cleveland Browns   7   8  1  0.469  359  392  -33  -2.1  1.7  -0.3
# 7     Cincinnati Bengals   6  10  0  0.375  368  455  -87  -5.4  2.0  -3.4
# 8         Houston Texans  11   5  0  0.688  402  316   86   5.4 -1.5   3.8
# 9     Indianapolis Colts  10   6  0  0.625  433  344   89   5.6 -2.2   3.4
# 10      Tennessee Titans   9   7  0  0.563  310  303    7   0.4 -0.2   0.2
# 11  Jacksonville Jaguars   5  11  0  0.313  245  316  -71  -4.4  0.4  -4.0
# 12    Kansas City Chiefs  12   4  0  0.750  565  421  144   9.0 -0.1   8.9
# 13  Los Angeles Chargers  12   4  0  0.750  428  329   99   6.2 -0.2   6.0
# 14        Denver Broncos   6  10  0  0.375  329  349  -20  -1.3  0.7  -0.5
# 15       Oakland Raiders   4  12  0  0.250  290  467 -177 -11.1  1.8  -9.3
# 16        Dallas Cowboys  10   6  0  0.625  339  324   15   0.9  0.2   1.1
# 17   Philadelphia Eagles   9   7  0  0.563  367  348   19   1.2  0.5   1.7
# 18   Washington Redskins   7   9  0  0.438  281  359  -78  -4.9 -0.1  -4.9
# 19       New York Giants   5  11  0  0.313  369  412  -43  -2.7  0.5  -2.2
# 20         Chicago Bears  12   4  0  0.750  421  283  138   8.6 -2.3   6.3
# 21     Minnesota Vikings   8   7  1  0.531  360  341   19   1.2 -0.6   0.6
# 22     Green Bay Packers   6   9  1  0.406  376  400  -24  -1.5 -1.2  -2.7
# 23         Detroit Lions   6  10  0  0.375  324  360  -36  -2.3 -0.8  -3.0
# 24    New Orleans Saints  13   3  0  0.813  504  353  151   9.4  0.6  10.1
# 25     Carolina Panthers   7   9  0  0.438  376  382   -6  -0.4  1.3   0.9
# 26       Atlanta Falcons   7   9  0  0.438  414  423   -9  -0.6  0.4  -0.1
# 27  Tampa Bay Buccaneers   5  11  0  0.313  396  464  -68  -4.3  1.7  -2.6
# 28      Los Angeles Rams  13   3  0  0.813  527  384  143   8.9 -0.4   8.5
# 29      Seattle Seahawks  10   6  0  0.625  428  347   81   5.1 -0.6   4.5
# 30   San Francisco 49ers   4  12  0  0.250  342  435  -93  -5.8  0.3  -5.5
# 31     Arizona Cardinals   3  13  0  0.188  225  425 -200 -12.5  1.0 -11.5
#
#     OSRS  DSRS
# 0    3.1   2.1
# 1   -3.6  -5.2
# 2   -6.3  -0.6
# 3   -2.0  -5.9
# 4    0.6   6.4
# 5    3.9   1.7
# 6   -1.0   0.6
# 7    0.0  -3.4
# 8    2.4   1.4
# 9    3.9  -0.6
# 10  -3.2   3.5
# 11  -8.1   4.0
# 12  12.6  -3.8
# 13   3.0   2.9
# 14  -3.6   3.1
# 15  -5.2  -4.1
# 16  -1.9   2.9
# 17   0.0   1.8
# 18  -5.6   0.6
# 19   0.8  -2.9
# 20   1.5   4.8
# 21  -1.2   1.8
# 22   0.0  -2.7
# 23  -3.3   0.3
# 24   7.9   2.2
# 25   0.1   0.8
# 26   2.5  -2.6
# 27   2.0  -4.6
# 28   9.5  -1.1
# 29   3.0   1.5
# 30  -2.5  -3.1
# 31  -9.6  -1.9

# %%
team_df = team_df.rename(columns = {"Tm":"Team"})
team_df
# Out:
#                     Team   W   L  T   W-L%   PF   PA   PD   MoV  SoS   SRS  \
# 0   New England Patriots  11   5  0  0.688  436  325  111   6.9 -1.8   5.2
# 1         Miami Dolphins   7   9  0  0.438  319  433 -114  -7.1 -1.7  -8.8
# 2          Buffalo Bills   6  10  0  0.375  269  374 -105  -6.6 -0.3  -6.9
# 3          New York Jets   4  12  0  0.250  333  441 -108  -6.8 -1.1  -7.8
# 4       Baltimore Ravens  10   6  0  0.625  389  287  102   6.4  0.6   7.0
# 5    Pittsburgh Steelers   9   6  1  0.594  428  360   68   4.3  1.3   5.6
# 6       Cleveland Browns   7   8  1  0.469  359  392  -33  -2.1  1.7  -0.3
# 7     Cincinnati Bengals   6  10  0  0.375  368  455  -87  -5.4  2.0  -3.4
# 8         Houston Texans  11   5  0  0.688  402  316   86   5.4 -1.5   3.8
# 9     Indianapolis Colts  10   6  0  0.625  433  344   89   5.6 -2.2   3.4
# 10      Tennessee Titans   9   7  0  0.563  310  303    7   0.4 -0.2   0.2
# 11  Jacksonville Jaguars   5  11  0  0.313  245  316  -71  -4.4  0.4  -4.0
# 12    Kansas City Chiefs  12   4  0  0.750  565  421  144   9.0 -0.1   8.9
# 13  Los Angeles Chargers  12   4  0  0.750  428  329   99   6.2 -0.2   6.0
# 14        Denver Broncos   6  10  0  0.375  329  349  -20  -1.3  0.7  -0.5
# 15       Oakland Raiders   4  12  0  0.250  290  467 -177 -11.1  1.8  -9.3
# 16        Dallas Cowboys  10   6  0  0.625  339  324   15   0.9  0.2   1.1
# 17   Philadelphia Eagles   9   7  0  0.563  367  348   19   1.2  0.5   1.7
# 18   Washington Redskins   7   9  0  0.438  281  359  -78  -4.9 -0.1  -4.9
# 19       New York Giants   5  11  0  0.313  369  412  -43  -2.7  0.5  -2.2
# 20         Chicago Bears  12   4  0  0.750  421  283  138   8.6 -2.3   6.3
# 21     Minnesota Vikings   8   7  1  0.531  360  341   19   1.2 -0.6   0.6
# 22     Green Bay Packers   6   9  1  0.406  376  400  -24  -1.5 -1.2  -2.7
# 23         Detroit Lions   6  10  0  0.375  324  360  -36  -2.3 -0.8  -3.0
# 24    New Orleans Saints  13   3  0  0.813  504  353  151   9.4  0.6  10.1
# 25     Carolina Panthers   7   9  0  0.438  376  382   -6  -0.4  1.3   0.9
# 26       Atlanta Falcons   7   9  0  0.438  414  423   -9  -0.6  0.4  -0.1
# 27  Tampa Bay Buccaneers   5  11  0  0.313  396  464  -68  -4.3  1.7  -2.6
# 28      Los Angeles Rams  13   3  0  0.813  527  384  143   8.9 -0.4   8.5
# 29      Seattle Seahawks  10   6  0  0.625  428  347   81   5.1 -0.6   4.5
# 30   San Francisco 49ers   4  12  0  0.250  342  435  -93  -5.8  0.3  -5.5
# 31     Arizona Cardinals   3  13  0  0.188  225  425 -200 -12.5  1.0 -11.5
#
#     OSRS  DSRS
# 0    3.1   2.1
# 1   -3.6  -5.2
# 2   -6.3  -0.6
# 3   -2.0  -5.9
# 4    0.6   6.4
# 5    3.9   1.7
# 6   -1.0   0.6
# 7    0.0  -3.4
# 8    2.4   1.4
# 9    3.9  -0.6
# 10  -3.2   3.5
# 11  -8.1   4.0
# 12  12.6  -3.8
# 13   3.0   2.9
# 14  -3.6   3.1
# 15  -5.2  -4.1
# 16  -1.9   2.9
# 17   0.0   1.8
# 18  -5.6   0.6
# 19   0.8  -2.9
# 20   1.5   4.8
# 21  -1.2   1.8
# 22   0.0  -2.7
# 23  -3.3   0.3
# 24   7.9   2.2
# 25   0.1   0.8
# 26   2.5  -2.6
# 27   2.0  -4.6
# 28   9.5  -1.1
# 29   3.0   1.5
# 30  -2.5  -3.1
# 31  -9.6  -1.9

# %%
team_df["Tm"] = ["NE","MIA","BUF","NYJ","BAL","PIT","CLE","CIN","HOU","IND","TEN","JAX","KC","LAC","DEN","OAK","DAL",
                 "PHI","WAS","NYG","CHI","MIN","GB","DET","NO","CAR","ALT","TB","LAR","SEA","SF","ARI"]
team_df
# Out:
#                     Team   W   L  T   W-L%   PF   PA   PD   MoV  SoS   SRS  \
# 0   New England Patriots  11   5  0  0.688  436  325  111   6.9 -1.8   5.2
# 1         Miami Dolphins   7   9  0  0.438  319  433 -114  -7.1 -1.7  -8.8
# 2          Buffalo Bills   6  10  0  0.375  269  374 -105  -6.6 -0.3  -6.9
# 3          New York Jets   4  12  0  0.250  333  441 -108  -6.8 -1.1  -7.8
# 4       Baltimore Ravens  10   6  0  0.625  389  287  102   6.4  0.6   7.0
# 5    Pittsburgh Steelers   9   6  1  0.594  428  360   68   4.3  1.3   5.6
# 6       Cleveland Browns   7   8  1  0.469  359  392  -33  -2.1  1.7  -0.3
# 7     Cincinnati Bengals   6  10  0  0.375  368  455  -87  -5.4  2.0  -3.4
# 8         Houston Texans  11   5  0  0.688  402  316   86   5.4 -1.5   3.8
# 9     Indianapolis Colts  10   6  0  0.625  433  344   89   5.6 -2.2   3.4
# 10      Tennessee Titans   9   7  0  0.563  310  303    7   0.4 -0.2   0.2
# 11  Jacksonville Jaguars   5  11  0  0.313  245  316  -71  -4.4  0.4  -4.0
# 12    Kansas City Chiefs  12   4  0  0.750  565  421  144   9.0 -0.1   8.9
# 13  Los Angeles Chargers  12   4  0  0.750  428  329   99   6.2 -0.2   6.0
# 14        Denver Broncos   6  10  0  0.375  329  349  -20  -1.3  0.7  -0.5
# 15       Oakland Raiders   4  12  0  0.250  290  467 -177 -11.1  1.8  -9.3
# 16        Dallas Cowboys  10   6  0  0.625  339  324   15   0.9  0.2   1.1
# 17   Philadelphia Eagles   9   7  0  0.563  367  348   19   1.2  0.5   1.7
# 18   Washington Redskins   7   9  0  0.438  281  359  -78  -4.9 -0.1  -4.9
# 19       New York Giants   5  11  0  0.313  369  412  -43  -2.7  0.5  -2.2
# 20         Chicago Bears  12   4  0  0.750  421  283  138   8.6 -2.3   6.3
# 21     Minnesota Vikings   8   7  1  0.531  360  341   19   1.2 -0.6   0.6
# 22     Green Bay Packers   6   9  1  0.406  376  400  -24  -1.5 -1.2  -2.7
# 23         Detroit Lions   6  10  0  0.375  324  360  -36  -2.3 -0.8  -3.0
# 24    New Orleans Saints  13   3  0  0.813  504  353  151   9.4  0.6  10.1
# 25     Carolina Panthers   7   9  0  0.438  376  382   -6  -0.4  1.3   0.9
# 26       Atlanta Falcons   7   9  0  0.438  414  423   -9  -0.6  0.4  -0.1
# 27  Tampa Bay Buccaneers   5  11  0  0.313  396  464  -68  -4.3  1.7  -2.6
# 28      Los Angeles Rams  13   3  0  0.813  527  384  143   8.9 -0.4   8.5
# 29      Seattle Seahawks  10   6  0  0.625  428  347   81   5.1 -0.6   4.5
# 30   San Francisco 49ers   4  12  0  0.250  342  435  -93  -5.8  0.3  -5.5
# 31     Arizona Cardinals   3  13  0  0.188  225  425 -200 -12.5  1.0 -11.5
#
#     OSRS  DSRS   Tm
# 0    3.1   2.1   NE
# 1   -3.6  -5.2  MIA
# 2   -6.3  -0.6  BUF
# 3   -2.0  -5.9  NYJ
# 4    0.6   6.4  BAL
# 5    3.9   1.7  PIT
# 6   -1.0   0.6  CLE
# 7    0.0  -3.4  CIN
# 8    2.4   1.4  HOU
# 9    3.9  -0.6  IND
# 10  -3.2   3.5  TEN
# 11  -8.1   4.0  JAX
# 12  12.6  -3.8   KC
# 13   3.0   2.9  LAC
# 14  -3.6   3.1  DEN
# 15  -5.2  -4.1  OAK
# 16  -1.9   2.9  DAL
# 17   0.0   1.8  PHI
# 18  -5.6   0.6  WAS
# 19   0.8  -2.9  NYG
# 20   1.5   4.8  CHI
# 21  -1.2   1.8  MIN
# 22   0.0  -2.7   GB
# 23  -3.3   0.3  DET
# 24   7.9   2.2   NO
# 25   0.1   0.8  CAR
# 26   2.5  -2.6  ALT
# 27   2.0  -4.6   TB
# 28   9.5  -1.1  LAR
# 29   3.0   1.5  SEA
# 30  -2.5  -3.1   SF
# 31  -9.6  -1.9  ARI

# %%
team_df.columns
# Out:
# Index(['Team', 'W', 'L', 'T', 'W-L%', 'PF', 'PA', 'PD', 'MoV', 'SoS', 'SRS',
#        'OSRS', 'DSRS', 'Tm'],
#       dtype='object')

# %%
team_df = team_df[['Team', 'Tm', 'W', 'L', 'T', 'W-L%', 'PF', 'PA', 'PD', 'MoV', 'SoS', 'SRS',
       'OSRS', 'DSRS']]
team_df.head()
# Out:
#                    Team   Tm   W   L  T   W-L%   PF   PA   PD  MoV  SoS  SRS  \
# 0  New England Patriots   NE  11   5  0  0.688  436  325  111  6.9 -1.8  5.2
# 1        Miami Dolphins  MIA   7   9  0  0.438  319  433 -114 -7.1 -1.7 -8.8
# 2         Buffalo Bills  BUF   6  10  0  0.375  269  374 -105 -6.6 -0.3 -6.9
# 3         New York Jets  NYJ   4  12  0  0.250  333  441 -108 -6.8 -1.1 -7.8
# 4      Baltimore Ravens  BAL  10   6  0  0.625  389  287  102  6.4  0.6  7.0
#
#    OSRS  DSRS
# 0   3.1   2.1
# 1  -3.6  -5.2
# 2  -6.3  -0.6
# 3  -2.0  -5.9
# 4   0.6   6.4

# %% [markdown]
# Transform data

# %%
team_df = team_df[['Team', 'Tm', 'W', 'L', 'T', 'W-L%', 'PF', 'PA', 'PD']].copy()
team_df.head()
# Out:
#                    Team   Tm   W   L  T   W-L%   PF   PA   PD
# 0  New England Patriots   NE  11   5  0  0.688  436  325  111
# 1        Miami Dolphins  MIA   7   9  0  0.438  319  433 -114
# 2         Buffalo Bills  BUF   6  10  0  0.375  269  374 -105
# 3         New York Jets  NYJ   4  12  0  0.250  333  441 -108
# 4      Baltimore Ravens  BAL  10   6  0  0.625  389  287  102

# %% [markdown]
# creat database connection

# %%
connection_string = "root:<root>@localhost/nfl_db"
engine = create_engine(f'mysql://{connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     353         if not self._use_threadlocal:
# --> 354             return _ConnectionFairy._checkout(self)
#     355
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     137                 with util.safe_reraise():
# --> 138                     self._dec_overflow()
#     139         else:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     134             try:
# --> 135                 return self._create_connection()
#     136             except:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     298
# --> 299         return _ConnectionRecord(self)
#     300
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     427         if connect:
# --> 428             self.__connect(first_connect_check=True)
#     429         self.finalize_callback = deque()
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     629             self.starttime = time.time()
# --> 630             connection = pool._invoke_creator(self)
#     631             pool.logger.debug("Created new connection %r", connection)
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     324         else:
# --> 325             self.connect()
#     326
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _request_authentication(self)
#     860         self.write_packet(data)
# --> 861         auth_packet = self._read_packet()
#     862
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'172.17.0.1' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-27-d72bc75a6b62> in <module>
# ----> 1 engine.table_names()
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in table_names(self, schema, connection)
#    2238         """
#    2239
# -> 2240         with self._optional_conn_ctx_manager(connection) as conn:
#    2241             if not schema:
#    2242                 schema = self.dialect.default_schema_name
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _optional_conn_ctx_manager(self, connection)
#    2022     def _optional_conn_ctx_manager(self, connection=None):
#    2023         if connection is None:
# -> 2024             with self._contextual_connect() as conn:
#    2025                 yield conn
#    2026         else:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2224         return self._connection_cls(
#    2225             self,
# -> 2226             self._wrap_pool_connect(self.pool.connect, None),
#    2227             close_with_result=close_with_result,
#    2228             **kwargs
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2264             if connection is None:
#    2265                 Connection._handle_dbapi_exception_noconnection(
# -> 2266                     e, dialect, self
#    2267                 )
#    2268             else:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1534             util.raise_from_cause(newraise, exc_info)
#    1535         elif should_wrap:
# -> 1536             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1537         else:
#    1538             util.reraise(*exc_info)
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2260         dialect = self.dialect
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#    2264             if connection is None:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     352         """
#     353         if not self._use_threadlocal:
# --> 354             return _ConnectionFairy._checkout(self)
#     355
#     356         try:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     749     def _checkout(cls, pool, threadconns=None, fairy=None):
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#     753             fairy._pool = pool
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     481     @classmethod
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#     485             dbapi_connection = rec.get_connection()
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             except:
#     137                 with util.safe_reraise():
# --> 138                     self._dec_overflow()
#     139         else:
#     140             return self._do_get()
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     127         if value.__traceback__ is not tb:
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#     131     def u(s):
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     133         if self._inc_overflow():
#     134             try:
# --> 135                 return self._create_connection()
#     136             except:
#     137                 with util.safe_reraise():
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     297         """Called by subclasses to create a new ConnectionRecord."""
#     298
# --> 299         return _ConnectionRecord(self)
#     300
#     301     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     426         self.__pool = pool
#     427         if connect:
# --> 428             self.__connect(first_connect_check=True)
#     429         self.finalize_callback = deque()
#     430
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     628         try:
#     629             self.starttime = time.time()
# --> 630             connection = pool._invoke_creator(self)
#     631             pool.logger.debug("Created new connection %r", connection)
#     632             self.connection = connection
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     451
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#     455     def create_connect_args(self, url):
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     597
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#     601             if self.sql_mode is not None:
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _request_authentication(self)
#     859
#     860         self.write_packet(data)
# --> 861         auth_packet = self._read_packet()
#     862
#     863         # if authentication method isn't accepted the first byte
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# /Applications/anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'172.17.0.1' (using password: YES)")
# (Background on this error at: http://sqlalche.me/e/e3q8)
